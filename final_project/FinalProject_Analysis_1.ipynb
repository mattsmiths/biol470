# %% [markdown]
# <a href="https://colab.research.google.com/github/mattsmiths/biol470/blob/main/final_project/FinalProject_Analysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Click to copy the class code repository
# !git clone https://github.com/mattsmiths/biol470.git
# Out:
# Cloning into 'biol470'...
# remote: Enumerating objects: 736, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 736 (delta 90), reused 97 (delta 66), pack-reused 595 (from 3)
# Receiving objects: 100% (736/736), 928.38 MiB | 29.52 MiB/s, done.
# Resolving deltas: 100% (248/248), done.
# Updating files: 100% (302/302), done.

# %%
#@title Click to import libraries
import cv2 as cv
import os
import matplotlib.pyplot as plt
import numpy as np
import glob
import pandas as pd

# %%
data1 = pd.read_csv('/content/biol470/final_project/control_bee_2/assay1_inf_bee_0408_2_opto_2026-04-08_16-35-41_arena_circle_1_key.csv')

# %%
data1.head()
# Out:
#    Unnamed: 0                                           filepath  x_min  \
# 0           0  /Volumes/SmithL0/2026/BIOL470/Final_Reorg/beha...   3055
# 1           1  /Volumes/SmithL0/2026/BIOL470/Final_Reorg/beha...   3054
# 2           2  /Volumes/SmithL0/2026/BIOL470/Final_Reorg/beha...   3054
# 3           3  /Volumes/SmithL0/2026/BIOL470/Final_Reorg/beha...   3052
# 4           4  /Volumes/SmithL0/2026/BIOL470/Final_Reorg/beha...   3047
#
#    y_min  x_max  y_max  detection_confidence
# 0   1700   3685   2169              0.924282
# 1   1699   3682   2169              0.920290
# 2   1698   3682   2169              0.912432
# 3   1701   3674   2169              0.899438
# 4   1703   3667   2168              0.885976

# %%
x_store = []
y_store = []

# Pulling out the centroid for each detection event
for ind,ele in enumerate(data1['x_min']):
  x_center = (ele+data1['x_max'][ind])/2
  y_center = (data1['y_min'][ind]+data1['y_max'][ind])/2
  x_store.append(x_center)
  y_store.append(y_center)

# %%
# Plotting the centroid in x-y space over time
plt.plot(x_store,y_store)

# %%
# Plotting the centroid in x-y space over time
plt.plot(x_store,y_store,color=(0.7,0.7,0.2),linewidth=3)
plt.xlabel('x-coordinates')
plt.ylabel('y-coordinates')
plt.title('Bee position over time')
plt.savefig('control_bee2_assay_1.pdf',dpi=200)
